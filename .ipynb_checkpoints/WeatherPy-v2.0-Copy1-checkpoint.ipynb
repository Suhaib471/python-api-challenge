# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
import openweathermapy as ow
import sys
sys.path.append('Desktop/CU-NYC-DATA-PT-10-2019-U-C/Homework/06-Python-APIs/python-api-challenge/starter_code/')
import exp

# Import API key
#from api_keys import api_key


#config
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 590

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create settings dictionary with information we're interested in
settings = {"units": "metric", "appid": api_key}

# Make a single test call on first city in list
current_weather_city_first = owm.get_current(cities[0], **settings)
print(f"Current weather object for {cities[0]}: {current_weather_city_first}.")
# Out:
# Current weather object for saint-philippe: {'coord': {'lon': -73.48, 'lat': 45.36}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -0.92, 'pressure': 1018, 'humidity': 63, 'temp_min': -2.78, 'temp_max': 1}, 'visibility': 14484, 'wind': {'speed': 10.8, 'deg': 180, 'gust': 14.4}, 'clouds': {'all': 90}, 'dt': 1575848223, 'sys': {'type': 1, 'id': 820, 'country': 'CA', 'sunrise': 1575807633, 'sunset': 1575839474}, 'timezone': -18000, 'id': 6138908, 'name': 'Saint-Philippe', 'cod': 200}.

# %%
# Import cities list into a DataFrame & rename columns 
column_names = ["City"]
cities_pd = pd.DataFrame(cities, columns=column_names)
cities_pd["Cloudiness"] = ""
cities_pd["Country"] = ""
cities_pd["Humidity"] = ""
cities_pd["Date"] = ""
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Max Temp"] = ""
cities_pd["Windspeed"] = ""
print(len(cities_pd))
cities_pd.head()
# Out:
# 590
#              City Cloudiness Country Humidity Date Lat Lng Max Temp Windspeed
# 0  saint-philippe
# 1           sitka
# 2         veraval
# 3          hobart
# 4         mareeba

# %%
# Make successive API calls for all cities in list and print output to dataframe
# Include a print log of each city as it'sbeing processed (with the city number and city name).

for index, row in cities_pd.iterrows():
    name = row["City"]
    try:
        print(f"Processing for {name}.")
        current_weather_city = owm.get_current(name, **settings)
        cities_pd.loc[index, "Cloudiness"] = current_weather_city["clouds"]["all"]
        cities_pd.loc[index, "Country"] = current_weather_city["sys"]["country"]
        cities_pd.loc[index, "Humidity"] = current_weather_city["main"]["humidity"]
        cities_pd.loc[index, "Date"] = current_weather_city["dt"]
        cities_pd.loc[index, "Lat"] = current_weather_city["coord"]["lat"]
        cities_pd.loc[index, "Lng"] = current_weather_city["coord"]["lon"]
        cities_pd.loc[index, "Max Temp"] = current_weather_city["main"]["temp_max"]
        cities_pd.loc[index, "Windspeed"] = current_weather_city["wind"]["speed"]
        print("_______________________________")
        
    except:
        print("Missing field/result... skipping.")
# Out:
# Processing for saint-philippe.
# _______________________________
# Processing for sitka.
# _______________________________
# Processing for veraval.
# _______________________________
# Processing for hobart.
# _______________________________
# Processing for mareeba.
# _______________________________
# Processing for isangel.
# _______________________________
# Processing for georgetown.
# _______________________________
# Processing for hilo.
# _______________________________
# Processing for rikitea.
# _______________________________
# Processing for kodiak.
# _______________________________
# Processing for guerrero negro.
# _______________________________
# Processing for yicheng.
# _______________________________
# Processing for busselton.
# _______________________________
# Processing for puerto ayora.
# _______________________________
# Processing for ilulissat.
# _______________________________
# Processing for punta arenas.
# _______________________________
# Processing for micheweni.
# _______________________________
# Processing for belem.
# _______________________________
# Processing for cidreira.
# _______________________________
# Processing for barrow.
# _______________________________
# Processing for bethel.
# _______________________________
# Processing for puerto penasco.
# _______________________________
# Processing for ribeira grande.
# _______________________________
# Processing for ushuaia.
# _______________________________
# Processing for raton.
# _______________________________
# Processing for komsomolskiy.
# _______________________________
# Processing for avarua.
# _______________________________
# Processing for touros.
# _______________________________
# Processing for mataura.
# _______________________________
# Processing for voh.
# _______________________________
# Processing for tank.
# _______________________________
# Processing for kushmurun.
# Missing field/result... skipping.
# Processing for akropong.
# _______________________________
# Processing for ritchie.
# _______________________________
# Processing for bonavista.
# _______________________________
# Processing for port elizabeth.
# _______________________________
# Processing for arraial do cabo.
# _______________________________
# Processing for oyama.
# _______________________________
# Processing for yellowknife.
# _______________________________
# Processing for illoqqortoormiut.
# Missing field/result... skipping.
# Processing for rio gallegos.
# _______________________________
# Processing for tasiilaq.
# _______________________________
# Processing for bluff.
# _______________________________
# Processing for ginir.
# _______________________________
# Processing for severo-kurilsk.
# _______________________________
# Processing for carnarvon.
# _______________________________
# Processing for aykhal.
# _______________________________
# Processing for atuona.
# _______________________________
# Processing for taolanaro.
# Missing field/result... skipping.
# Processing for new norfolk.
# _______________________________
# Processing for kijang.
# _______________________________
# Processing for itainopolis.
# Missing field/result... skipping.
# Processing for east london.
# _______________________________
# Processing for zhigansk.
# _______________________________
# Processing for taybad.
# _______________________________
# Processing for anshun.
# _______________________________
# Processing for bredasdorp.
# _______________________________
# Processing for kulhudhuffushi.
# _______________________________
# Processing for baijiantan.
# _______________________________
# Processing for nelson bay.
# _______________________________
# Processing for codrington.
# _______________________________
# Processing for grand river south east.
# Missing field/result... skipping.
# Processing for kapaa.
# _______________________________
# Processing for menongue.
# _______________________________
# Processing for naze.
# _______________________________
# Processing for upernavik.
# _______________________________
# Processing for chokurdakh.
# _______________________________
# Processing for barbar.
# Missing field/result... skipping.
# Processing for aklavik.
# _______________________________
# Processing for cabedelo.
# _______________________________
# Processing for abu kamal.
# _______________________________
# Processing for tuatapere.
# _______________________________
# Processing for ponta do sol.
# _______________________________
# Processing for comodoro rivadavia.
# _______________________________
# Processing for san ramon de la nueva oran.
# _______________________________
# Processing for port alfred.
# _______________________________
# Processing for norman wells.
# _______________________________
# Processing for cochrane.
# _______________________________
# Processing for yulara.
# _______________________________
# Processing for mogadishu.
# _______________________________
# Processing for qaanaaq.
# _______________________________
# Processing for hermanus.
# _______________________________
# Processing for esperance.
# _______________________________
# Processing for attawapiskat.
# Missing field/result... skipping.
# Processing for cherskiy.
# _______________________________
# Processing for arrecife.
# Missing field/result... skipping.
# Processing for arica.
# _______________________________
# Processing for kieta.
# _______________________________
# Processing for bengkulu.
# Missing field/result... skipping.
# Processing for asau.
# Missing field/result... skipping.
# Processing for tres arroyos.
# _______________________________
# Processing for ostrovnoy.
# _______________________________
# Processing for airai.
# _______________________________
# Processing for klaksvik.
# _______________________________
# Processing for nizhneyansk.
# Missing field/result... skipping.
# Processing for hithadhoo.
# _______________________________
# Processing for kahului.
# _______________________________
# Processing for bela vista.
# _______________________________
# Processing for egvekinot.
# _______________________________
# Processing for tateyama.
# _______________________________
# Processing for pyshchug.
# _______________________________
# Processing for quelimane.
# _______________________________
# Processing for sao filipe.
# _______________________________
# Processing for moranbah.
# _______________________________
# Processing for makarov.
# _______________________________
# Processing for javanrud.
# _______________________________
# Processing for rawson.
# _______________________________
# Processing for longyan.
# _______________________________
# Processing for margate.
# _______________________________
# Processing for mar del plata.
# _______________________________
# Processing for gigmoto.
# _______________________________
# Processing for vaitupu.
# Missing field/result... skipping.
# Processing for mbalmayo.
# _______________________________
# Processing for etne.
# _______________________________
# Processing for kampene.
# _______________________________
# Processing for port blair.
# _______________________________
# Processing for beyneu.
# _______________________________
# Processing for butaritari.
# _______________________________
# Processing for tsihombe.
# Missing field/result... skipping.
# Processing for pevek.
# _______________________________
# Processing for jacareacanga.
# _______________________________
# Processing for lazaro cardenas.
# _______________________________
# Processing for khatanga.
# _______________________________
# Processing for sakakah.
# Missing field/result... skipping.
# Processing for salalah.
# _______________________________
# Processing for flagstaff.
# _______________________________
# Processing for la sarre.
# _______________________________
# Processing for tautira.
# _______________________________
# Processing for presidencia roque saenz pena.
# _______________________________
# Processing for flin flon.
# _______________________________
# Processing for lorengau.
# _______________________________
# Processing for russell.
# _______________________________
# Processing for jamestown.
# _______________________________
# Processing for arkhipo-osipovka.
# _______________________________
# Processing for cedar city.
# _______________________________
# Processing for bambous virieux.
# _______________________________
# Processing for bilsi.
# _______________________________
# Processing for samusu.
# Missing field/result... skipping.
# Processing for takoradi.
# _______________________________
# Processing for disna.
# Missing field/result... skipping.
# Processing for cururupu.
# _______________________________
# Processing for souillac.
# _______________________________
# Processing for rhyl.
# _______________________________
# Processing for grand gaube.
# _______________________________
# Processing for nome.
# _______________________________
# Processing for tuktoyaktuk.
# _______________________________
# Processing for vaini.
# _______________________________
# Processing for visnes.
# _______________________________
# Processing for gizo.
# _______________________________
# Processing for villa bruzual.
# _______________________________
# Processing for hasaki.
# _______________________________
# Processing for lethem.
# _______________________________
# Processing for longyearbyen.
# _______________________________
# Processing for rungata.
# Missing field/result... skipping.
# Processing for luwuk.
# _______________________________
# Processing for fortuna.
# _______________________________
# Processing for ciudad bolivar.
# _______________________________
# Processing for khanu woralaksaburi.
# _______________________________
# Processing for la primavera.
# _______________________________
# Processing for khonuu.
# Missing field/result... skipping.
# Processing for kaniama.
# _______________________________
# Processing for albany.
# _______________________________
# Processing for jilin.
# _______________________________
# Processing for antanifotsy.
# _______________________________
# Processing for coquimbo.
# _______________________________
# Processing for saskylakh.
# _______________________________
# Processing for houston.
# _______________________________
# Processing for challans.
# _______________________________
# Processing for easley.
# _______________________________
# Processing for marawi.
# _______________________________
# Processing for cape town.
# _______________________________
# Processing for diego de almagro.
# _______________________________
# Processing for belushya guba.
# Missing field/result... skipping.
# Processing for hauknes.
# _______________________________
# Processing for hokitika.
# _______________________________
# Processing for ambulu.
# _______________________________
# Processing for alta floresta.
# _______________________________
# Processing for pio xii.
# _______________________________
# Processing for sentyabrskiy.
# Missing field/result... skipping.
# Processing for mount isa.
# _______________________________
# Processing for cosala.
# Missing field/result... skipping.
# Processing for te anau.
# _______________________________
# Processing for brae.
# _______________________________
# Processing for hamilton.
# _______________________________
# Processing for saint-pierre.
# _______________________________
# Processing for tamandare.
# _______________________________
# Processing for castro.
# _______________________________
# Processing for thompson.
# _______________________________
# Processing for nikolskoye.
# _______________________________
# Processing for hofn.
# _______________________________
# Processing for fort nelson.
# _______________________________
# Processing for amderma.
# Missing field/result... skipping.
# Processing for luderitz.
# _______________________________
# Processing for richards bay.
# _______________________________
# Processing for elko.
# _______________________________
# Processing for carthage.
# _______________________________
# Processing for ayan.
# _______________________________
# Processing for yarmouth.
# _______________________________
# Processing for rosario.
# _______________________________
# Processing for sorong.
# _______________________________
# Processing for zhoucheng.
# _______________________________
# Processing for cam ranh.
# _______________________________
# Processing for hailar.
# _______________________________
# Processing for jawhar.
# _______________________________
# Processing for san policarpo.
# _______________________________
# Processing for katsuura.
# _______________________________
# Processing for bilma.
# _______________________________
# Processing for zyryanka.
# _______________________________
# Processing for domoni.
# Missing field/result... skipping.
# Processing for kyabe.
# _______________________________
# Processing for celestun.
# _______________________________
# Processing for kruisfontein.
# _______________________________
# Processing for trairi.
# _______________________________
# Processing for srednekolymsk.
# _______________________________
# Processing for high level.
# _______________________________
# Processing for biak.
# _______________________________
# Processing for akkermanovka.
# Missing field/result... skipping.
# Processing for nohfelden.
# _______________________________
# Processing for sept-iles.
# _______________________________
# Processing for talnakh.
# _______________________________
# Processing for iqaluit.
# _______________________________
# Processing for kazalinsk.
# Missing field/result... skipping.
# Processing for wahpeton.
# _______________________________
# Processing for ancud.
# _______________________________
# Processing for khandyga.
# _______________________________
# Processing for kinsale.
# _______________________________
# Processing for tiksi.
# _______________________________
# Processing for sao francisco.
# _______________________________
# Processing for nyahururu.
# _______________________________
# Processing for tabiauea.
# Missing field/result... skipping.
# Processing for karauli.
# _______________________________
# Processing for gonda.
# _______________________________
# Processing for kuytun.
# _______________________________
# Processing for lompoc.
# _______________________________
# Processing for boyolangu.
# _______________________________
# Processing for carnot.
# _______________________________
# Processing for kavieng.
# _______________________________
# Processing for pontarlier.
# _______________________________
# Processing for buena vista.
# _______________________________
# Processing for lavrentiya.
# _______________________________
# Processing for sao joao da barra.
# _______________________________
# Processing for vestmanna.
# _______________________________
# Processing for martapura.
# _______________________________
# Processing for nizwa.
# _______________________________
# Processing for pandan.
# _______________________________
# Processing for sokoto.
# _______________________________
# Processing for saldanha.
# _______________________________
# Processing for toftir.
# Missing field/result... skipping.
# Processing for bandarbeyla.
# _______________________________
# Processing for aden.
# _______________________________
# Processing for vage.
# Missing field/result... skipping.
# Processing for puerto baquerizo moreno.
# _______________________________
# Processing for santo antonio do ica.
# _______________________________
# Processing for san cristobal.
# _______________________________
# Processing for torbay.
# _______________________________
# Processing for mitsamiouli.
# _______________________________
# Processing for roebourne.
# _______________________________
# Processing for progreso.
# _______________________________
# Processing for san patricio.
# _______________________________
# Processing for lagoa.
# _______________________________
# Processing for roald.
# _______________________________
# Processing for nouadhibou.
# _______________________________
# Processing for kollumerland.
# Missing field/result... skipping.
# Processing for victoria.
# _______________________________
# Processing for denpasar.
# _______________________________
# Processing for gamba.
# _______________________________
# Processing for duyun.
# _______________________________
# Processing for oranjemund.
# _______________________________
# Processing for pascagoula.
# _______________________________
# Processing for san roque.
# _______________________________
# Processing for soubre.
# _______________________________
# Processing for the valley.
# _______________________________
# Processing for ryotsu.
# _______________________________
# Processing for puerto escondido.
# _______________________________
# Processing for linqiong.
# _______________________________
# Processing for geraldton.
# _______________________________
# Processing for hauterive.
# _______________________________
# Processing for chuy.
# _______________________________
# Processing for cayenne.
# _______________________________
# Processing for garden city.
# _______________________________
# Processing for nanortalik.
# _______________________________
# Processing for northam.
# _______________________________
# Processing for quang ngai.
# _______________________________
# Processing for bago.
# _______________________________
# Processing for ewa beach.
# _______________________________
# Processing for itarema.
# _______________________________
# Processing for walvis bay.
# _______________________________
# Processing for vila velha.
# _______________________________
# Processing for najran.
# _______________________________
# Processing for san jose.
# _______________________________
# Processing for dikson.
# _______________________________
# Processing for cabo san lucas.
# _______________________________
# Processing for huangmei.
# _______________________________
# Processing for atambua.
# _______________________________
# Processing for along.
# _______________________________
# Processing for rudbar.
# Missing field/result... skipping.
# Processing for khanpur.
# _______________________________
# Processing for taltal.
# _______________________________
# Processing for rafaela.
# _______________________________
# Processing for faanui.
# _______________________________
# Processing for anloga.
# _______________________________
# Processing for ust-nera.
# _______________________________
# Processing for griffith.
# _______________________________
# Processing for puri.
# _______________________________
# Processing for lima.
# _______________________________
# Processing for lala.
# _______________________________
# Processing for la palma.
# _______________________________
# Processing for marcona.
# Missing field/result... skipping.
# Processing for karratha.
# _______________________________
# Processing for malanje.
# _______________________________
# Processing for bolungarvik.
# Missing field/result... skipping.
# Processing for lebu.
# _______________________________
# Processing for macas.
# _______________________________
# Processing for channel-port aux basques.
# _______________________________
# Processing for southbridge.
# _______________________________
# Processing for ahipara.
# _______________________________
# Processing for bowen.
# _______________________________
# Processing for urumqi.
# Missing field/result... skipping.
# Processing for cam pha.
# Missing field/result... skipping.
# Processing for valley city.
# _______________________________
# Processing for beira.
# _______________________________
# Processing for coahuayana.
# _______________________________
# Processing for colorado.
# _______________________________
# Processing for killybegs.
# _______________________________
# Processing for mys shmidta.
# Missing field/result... skipping.
# Processing for swakopmund.
# _______________________________
# Processing for bismarck.
# _______________________________
# Processing for tyup.
# _______________________________
# Processing for vastseliina.
# _______________________________
# Processing for dodge city.
# _______________________________
# Processing for tumannyy.
# Missing field/result... skipping.
# Processing for quatis.
# _______________________________
# Processing for kodinsk.
# _______________________________
# Processing for berdigestyakh.
# _______________________________
# Processing for haines junction.
# _______________________________
# Processing for newport.
# _______________________________
# Processing for markova.
# _______________________________
# Processing for alamos.
# _______________________________
# Processing for miri.
# _______________________________
# Processing for petropavlovsk-kamchatskiy.
# _______________________________
# Processing for kuminskiy.
# _______________________________
# Processing for saint-joseph.
# _______________________________
# Processing for ormara.
# _______________________________
# Processing for saint anthony.
# _______________________________
# Processing for lohardaga.
# _______________________________
# Processing for rocha.
# _______________________________
# Processing for kaitangata.
# _______________________________
# Processing for leningradskiy.
# _______________________________
# Processing for tahe.
# _______________________________
# Processing for saint george.
# _______________________________
# Processing for pangnirtung.
# _______________________________
# Processing for angoche.
# _______________________________
# Processing for marrakesh.
# _______________________________
# Processing for dickinson.
# _______________________________
# Processing for pisco.
# _______________________________
# Processing for sabla.
# _______________________________
# Processing for kpandae.
# _______________________________
# Processing for atasu.
# _______________________________
# Processing for nandikotkur.
# _______________________________
# Processing for bardiyah.
# Missing field/result... skipping.
# Processing for great yarmouth.
# _______________________________
# Processing for kizukuri.
# _______________________________
# Processing for malwan.
# Missing field/result... skipping.
# Processing for port keats.
# _______________________________
# Processing for luanda.
# _______________________________
# Processing for awbari.
# _______________________________
# Processing for dingle.
# _______________________________
# Processing for krasnovishersk.
# _______________________________
# Processing for sabang.
# _______________________________
# Processing for xuddur.
# _______________________________
# Processing for samalaeulu.
# Missing field/result... skipping.
# Processing for mugur-aksy.
# _______________________________
# Processing for aras.
# _______________________________
# Processing for dzaoudzi.
# _______________________________
# Processing for novyy karachay.
# _______________________________
# Processing for kasongo-lunda.
# _______________________________
# Processing for hobyo.
# _______________________________
# Processing for lolua.
# Missing field/result... skipping.
# Processing for malyye derbety.
# _______________________________
# Processing for sur.
# _______________________________
# Processing for ilinskiy.
# _______________________________
# Processing for tura.
# _______________________________
# Processing for paramirim.
# _______________________________
# Processing for kampot.
# _______________________________
# Processing for tarata.
# _______________________________
# Processing for meulaboh.
# _______________________________
# Processing for salinopolis.
# _______________________________
# Processing for sibenik.
# _______________________________
# Processing for jobabo.
# _______________________________
# Processing for mayumba.
# _______________________________
# Processing for lata.
# _______________________________
# Processing for tsienyane.
# Missing field/result... skipping.
# Processing for pitimbu.
# _______________________________
# Processing for ekuvukeni.
# _______________________________
# Processing for langfang.
# _______________________________
# Processing for gillette.
# _______________________________
# Processing for tarko-sale.
# _______________________________
# Processing for necochea.
# _______________________________
# Processing for prieska.
# _______________________________
# Processing for itoman.
# _______________________________
# Processing for colesberg.
# _______________________________
# Processing for krasnoselkup.
# Missing field/result... skipping.
# Processing for samarai.
# _______________________________
# Processing for xinzhi.
# _______________________________
# Processing for jinchang.
# _______________________________
# Processing for halifax.
# _______________________________
# Processing for anadyr.
# _______________________________
# Processing for kloulklubed.
# _______________________________
# Processing for north bend.
# _______________________________
# Processing for bandipur.
# _______________________________
# Processing for provideniya.
# _______________________________
# Processing for price.
# _______________________________
# Processing for dolgorukovo.
# _______________________________
# Processing for polis.
# _______________________________
# Processing for chicama.
# _______________________________
# Processing for mahebourg.
# _______________________________
# Processing for karkaralinsk.
# Missing field/result... skipping.
# Processing for stoyba.
# Missing field/result... skipping.
# Processing for grindavik.
# _______________________________
# Processing for pangani.
# _______________________________
# Processing for zeya.
# _______________________________
# Processing for srinagar.
# _______________________________
# Processing for basco.
# _______________________________
# Processing for barentsburg.
# Missing field/result... skipping.
# Processing for tunceli.
# _______________________________
# Processing for oussouye.
# _______________________________
# Processing for muika.
# Missing field/result... skipping.
# Processing for barentu.
# _______________________________
# Processing for chapais.
# _______________________________
# Processing for portland.
# _______________________________
# Processing for marang.
# Missing field/result... skipping.
# Processing for kralendijk.
# _______________________________
# Processing for hollins.
# _______________________________
# Processing for katobu.
# _______________________________
# Processing for tapaua.
# Missing field/result... skipping.
# Processing for namibe.
# _______________________________
# Processing for kuching.
# _______________________________
# Processing for limon.
# _______________________________
# Processing for bazaliya.
# _______________________________
# Processing for ayolas.
# _______________________________
# Processing for palana.
# _______________________________
# Processing for we.
# Missing field/result... skipping.
# Processing for straumen.
# _______________________________
# Processing for tabuk.
# _______________________________
# Processing for carauari.
# _______________________________
# Processing for vardo.
# _______________________________
# Processing for tomatlan.
# _______________________________
# Processing for jiddah.
# Missing field/result... skipping.
# Processing for barra do corda.
# _______________________________
# Processing for muros.
# _______________________________
# Processing for kavaratti.
# _______________________________
# Processing for westport.
# _______________________________
# Processing for turukhansk.
# _______________________________
# Processing for tazovskiy.
# _______________________________
# Processing for kamenskoye.
# Missing field/result... skipping.
# Processing for alotau.
# Missing field/result... skipping.
# Processing for kitgum.
# _______________________________
# Processing for hlotse.
# Missing field/result... skipping.
# Processing for pangai.
# _______________________________
# Processing for whitehorse.
# _______________________________
# Processing for hambantota.
# _______________________________
# Processing for aswan.
# _______________________________
# Processing for tres coracoes.
# _______________________________
# Processing for adrar.
# _______________________________
# Processing for lubin.
# _______________________________
# Processing for belmonte.
# _______________________________
# Processing for safaga.
# Missing field/result... skipping.
# Processing for puerto castilla.
# _______________________________
# Processing for constitucion.
# _______________________________
# Processing for camacha.
# _______________________________
# Processing for sungaipenuh.
# _______________________________
# Processing for annau.
# _______________________________
# Processing for abu samrah.
# _______________________________
# Processing for marakkanam.
# _______________________________
# Processing for qasigiannguit.
# _______________________________
# Processing for mackay.
# _______________________________
# Processing for port lincoln.
# _______________________________
# Processing for port hedland.
# _______________________________
# Processing for kilindoni.
# _______________________________
# Processing for fare.
# _______________________________
# Processing for tukrah.
# Missing field/result... skipping.
# Processing for la tijera.
# _______________________________
# Processing for shibarghan.
# Missing field/result... skipping.
# Processing for hualmay.
# _______________________________
# Processing for daoukro.
# _______________________________
# Processing for amapa.
# _______________________________
# Processing for sovetskoye.
# _______________________________
# Processing for rwamagana.
# _______________________________
# Processing for iquitos.
# _______________________________
# Processing for la ronge.
# _______________________________
# Processing for baoding.
# _______________________________
# Processing for nishihara.
# _______________________________
# Processing for cockburn town.
# _______________________________
# Processing for saleaula.
# Missing field/result... skipping.
# Processing for marienburg.
# _______________________________
# Processing for guarapari.
# _______________________________
# Processing for ratchaburi.
# _______________________________
# Processing for bhinga.
# _______________________________
# Processing for bathsheba.
# _______________________________
# Processing for cheuskiny.
# Missing field/result... skipping.
# Processing for muisne.
# _______________________________
# Processing for emerald.
# _______________________________
# Processing for ridgecrest.
# _______________________________
# Processing for kungurtug.
# _______________________________
# Processing for wasilla.
# _______________________________
# Processing for tilichiki.
# _______________________________
# Processing for caravelas.
# _______________________________
# Processing for digboi.
# _______________________________
# Processing for palembang.
# _______________________________
# Processing for coos bay.
# _______________________________
# Processing for mount gambier.
# _______________________________
# Processing for kiruna.
# _______________________________
# Processing for umzimvubu.
# Missing field/result... skipping.
# Processing for taoudenni.
# _______________________________
# Processing for humaita.
# _______________________________
# Processing for ascension.
# Missing field/result... skipping.
# Processing for tiarei.
# _______________________________
# Processing for fillan.
# _______________________________
# Processing for hihifo.
# Missing field/result... skipping.
# Processing for sinnamary.
# _______________________________
# Processing for jalu.
# _______________________________
# Processing for teshie.
# _______________________________
# Processing for egersund.
# _______________________________
# Processing for macapa.
# _______________________________
# Processing for mananjary.
# _______________________________
# Processing for port hardy.
# _______________________________
# Processing for karamea.
# Missing field/result... skipping.
# Processing for shahr-e kord.
# _______________________________
# Processing for leopoldina.
# _______________________________
# Processing for santiago.
# _______________________________
# Processing for mehamn.
# _______________________________
# Processing for raga.
# Missing field/result... skipping.
# Processing for road town.
# _______________________________
# Processing for barawe.
# Missing field/result... skipping.
# Processing for port macquarie.
# _______________________________
# Processing for port said.
# _______________________________
# Processing for carbonia.
# _______________________________
# Processing for poum.
# _______________________________
# Processing for zemio.
# _______________________________
# Processing for hovd.
# _______________________________
# Processing for qurayyat.
# Missing field/result... skipping.
# Processing for krasnokamensk.
# _______________________________
# Processing for nianzishan.
# _______________________________
# Processing for half moon bay.
# _______________________________
# Processing for ondorhaan.
# Missing field/result... skipping.
# Processing for tsabong.
# _______________________________
# Processing for jabiru.
# Missing field/result... skipping.
# Processing for karaul.
# Missing field/result... skipping.
# Processing for port-gentil.
# _______________________________
# Processing for vreed en hoop.
# Missing field/result... skipping.
# Processing for rognan.
# _______________________________
# Processing for samarkand.
# _______________________________
# Processing for mao.
# _______________________________
# Processing for broken hill.
# _______________________________
# Processing for manokwari.
# _______________________________
# Processing for north battleford.
# _______________________________
# Processing for zhezkazgan.
# _______________________________
# Processing for khash.
# _______________________________
# Processing for natitingou.
# _______________________________
# Processing for ayna.
# _______________________________
# Processing for mandalgovi.
# _______________________________
# Processing for podosinovets.
# _______________________________
# Processing for tigil.
# _______________________________
# Processing for birnin kebbi.
# _______________________________
# Processing for orchard homes.
# _______________________________
# Processing for lodja.
# _______________________________
# Processing for monte azul.
# _______________________________
# Processing for bundaberg.
# _______________________________
# Processing for linxia.
# _______________________________
# Processing for harper.
# _______________________________
# Processing for talcahuano.
# _______________________________
# Processing for gobabis.
# _______________________________
# Processing for henzada.
# Missing field/result... skipping.
# Processing for doha.
# _______________________________
# Processing for noyabrsk.
# _______________________________
# Processing for lakheri.
# _______________________________
# Processing for bay roberts.
# _______________________________
# Processing for manta.
# _______________________________
# Processing for tevriz.
# _______________________________
# Processing for solnechnyy.
# _______________________________
# Processing for black river.
# _______________________________
# Processing for sisimiut.
# _______________________________
# Processing for baruun-urt.
# _______________________________
# Processing for elliot lake.
# _______________________________
# Processing for atar.
# _______________________________
# Processing for watertown.
# _______________________________
# Processing for paamiut.
# _______________________________
# Processing for barmstedt.
# _______________________________
# Processing for divnomorskoye.
# _______________________________
# Processing for avera.
# _______________________________

# %%
cities_pd = cities_pd.dropna(how='any')
cities_pd["Max Temp"] = pd.to_numeric(cities_pd["Max Temp"])
cities_pd["Lat"] = pd.to_numeric(cities_pd["Lat"])
cities_pd["Lng"] = pd.to_numeric(cities_pd["Lng"])
cities_pd["Cloudiness"] = pd.to_numeric(cities_pd["Cloudiness"])
cities_pd["Humidity"] = pd.to_numeric(cities_pd["Humidity"])
cities_pd["Windspeed"] = pd.to_numeric(cities_pd["Windspeed"])
print(len(cities_pd))
cities_pd.dtypes
# Out:
# 590
# City           object
# Cloudiness    float64
# Country        object
# Humidity      float64
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Windspeed     float64
# dtype: object

# %%
cities_pd.head(35)
# Out:
#               City  Cloudiness Country  Humidity        Date    Lat     Lng  \
# 0   saint-philippe        90.0      CA      63.0  1575848223  45.36  -73.48
# 1            sitka        98.0      US      58.0  1575848238  37.17  -99.65
# 2          veraval        67.0      FR      93.0  1575848238  49.65    0.71
# 3           hobart        75.0      AU      35.0  1575848002 -42.88  147.33
# 4          mareeba        40.0      AU      48.0  1575848238 -16.99  145.42
# 5          isangel        75.0      VU      66.0  1575848238 -19.55  169.27
# 6       georgetown        40.0      GY      88.0  1575848165   6.80  -58.16
# 7             hilo        40.0      US      69.0  1575848238  19.71 -155.08
# 8          rikitea        99.0      PF      81.0  1575848238 -23.12 -134.97
# 9           kodiak        90.0      US      81.0  1575848239  39.95  -94.76
# 10  guerrero negro       100.0      MX      67.0  1575848239  27.97 -114.04
# 11         yicheng       100.0      CN      71.0  1575848239  31.71  112.27
# 12       busselton         2.0      AU      35.0  1575848239 -33.64  115.35
# 13    puerto ayora        20.0      EC      78.0  1575848239  -0.74  -90.35
# 14       ilulissat        61.0      GL      45.0  1575848239  69.22  -51.10
# 15    punta arenas        90.0      CL      81.0  1575848239 -53.16  -70.91
# 16       micheweni        29.0      TZ      77.0  1575848239  -4.97   39.83
# 17           belem       100.0      BR      93.0  1575848239  -6.45  -64.49
# 18        cidreira        26.0      BR      86.0  1575848240 -30.17  -50.22
# 19          barrow         0.0      AR      69.0  1575848240 -38.31  -60.23
# 20          bethel         1.0      US      79.0  1575848240  60.79 -161.76
# 21  puerto penasco       100.0      MX      87.0  1575848168  31.32 -113.53
# 22  ribeira grande        75.0      PT      90.0  1575848240  38.52  -28.70
# 23         ushuaia        90.0      AR      87.0  1575847817 -54.81  -68.31
# 24           raton         1.0      US      37.0  1575848240  36.90 -104.44
# 25    komsomolskiy       100.0      RU      94.0  1575848240  67.55   63.78
# 26          avarua        84.0      CK      69.0  1575848240 -21.21 -159.78
# 27          touros        20.0      BR      78.0  1575848240  -5.20  -35.46
# 28         mataura        56.0      NZ      69.0  1575848240 -46.19  168.86
# 29             voh       100.0      NC      85.0  1575848240 -20.95  164.69
# 30            tank       100.0      PK      31.0  1575848241  32.22   70.39
# 31       kushmurun         NaN               NaN                NaN     NaN
# 32        akropong        20.0      GH      83.0  1575848241   5.97   -0.09
# 33         ritchie        20.0      ZA      68.0  1575848241 -29.03   24.60
# 34       bonavista        99.0      CA      79.0  1575848241  48.65  -53.11
#
#     Max Temp  Windspeed
# 0       1.00      10.80
# 1       9.90       1.92
# 2       8.00       8.20
# 3      23.33       5.70
# 4      31.11       5.10
# 5      30.00       2.60
# 6      26.00       8.77
# 7      27.00       3.10
# 8      23.24      11.30
# 9       9.44       2.60
# 10     20.80       5.25
# 11      7.51       2.96
# 12     22.22       3.51
# 13     24.00       7.20
# 14    -17.00       1.00
# 15     12.00       5.70
# 16     28.85       6.50
# 17     24.66       1.09
# 18     22.13       8.66
# 19     14.88       3.50
# 20      0.00       4.10
# 21     19.44       0.45
# 22     16.52       5.24
# 23      7.00       6.20
# 24     11.00      11.30
# 25     -9.75       7.00
# 26     27.00       8.20
# 27     27.00       6.20
# 28     12.78       5.81
# 29     25.95       7.18
# 30     14.44       0.32
# 31       NaN        NaN
# 32     28.00       4.10
# 33     19.00       5.10
# 34     -3.89       8.05

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
#### Latitude vs. Temperature Plot
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Max Temp"]
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Temperature (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.show()

# %%
#Bonus Visualization: Bivariate chart with added hue for longitude   
exp.plot_bivariate(cities_pd, 'Lat', 'Max Temp', hue='Lng', alpha=1.0)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Humidity"]
colors = ("green")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Humidity (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %%
#Bonus Visualization: Bivariate chart with added hue for longitude   
exp.plot_bivariate(cities_pd, 'Lat', 'Humidity', hue='Lng', alpha=1.0)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Cloudiness"]
colors = ("red")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Cloudiness (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %%
#Bonus Visualization: Bivariate chart with added hue for longitude   
exp.plot_bivariate(cities_pd, 'Lat', 'Cloudiness', hue='Lng', alpha=1.0)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Windspeed"]
colors = ("brown")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Windspeed (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %%
#Bonus Visualization: Bivariate chart with added hue for longitude   
exp.plot_bivariate(cities_pd, 'Lat', 'Windspeed', hue='Lng', alpha=1.0)
