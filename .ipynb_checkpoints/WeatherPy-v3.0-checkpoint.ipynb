# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
import openweathermapy as ow
import sys
sys.path.append('Desktop/CU-NYC-DATA-PT-10-2019-U-C/Homework/06-Python-APIs/python-api-challenge/starter_code/')
import exp

# Import API key
from api_keys import api_key


#config
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create settings dictionary with information we're interested in
settings = {"units": "metric", "appid": api_key}

# Make a single test call on first city in list
current_weather_city_first = owm.get_current(cities[0], **settings)
print(f"Current weather object for {cities[0]}: {current_weather_city_first}.")
# Out:
# Current weather object for phalaborwa: {'coord': {'lon': 31.14, 'lat': -23.95}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 22, 'feels_like': 25.13, 'temp_min': 22, 'temp_max': 22, 'pressure': 1012, 'humidity': 94}, 'wind': {'speed': 1.5, 'deg': 190}, 'rain': {'3h': 0.12}, 'clouds': {'all': 52}, 'dt': 1576111102, 'sys': {'type': 1, 'id': 1915, 'country': 'ZA', 'sunrise': 1576119687, 'sunset': 1576168599}, 'timezone': 7200, 'id': 965528, 'name': 'Phalaborwa', 'cod': 200}.

# %%
# Import cities list into a DataFrame & rename columns 
column_names = ["City"]
cities_pd = pd.DataFrame(cities, columns=column_names)
cities_pd["Cloudiness"] = ""
cities_pd["Country"] = ""
cities_pd["Humidity"] = ""
cities_pd["Date"] = ""
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Max Temp"] = ""
cities_pd["Windspeed"] = ""
print(len(cities_pd))
cities_pd.head()
# Out:
# 616
#            City Cloudiness Country Humidity Date Lat Lng Max Temp Windspeed
# 0    phalaborwa
# 1      uyemskiy
# 2  puerto ayora
# 3         vaini
# 4   tuktoyaktuk

# %%
# Make successive API calls for all cities in list and print output to dataframe
# Include a print log of each city as it'sbeing processed (with the city number and city name).

for index, row in cities_pd.iterrows():
    name = row["City"]
    try:
        print(f"Processing for {name}.")
        current_weather_city = owm.get_current(name, **settings)
        cities_pd.loc[index, "Cloudiness"] = current_weather_city["clouds"]["all"]
        cities_pd.loc[index, "Country"] = current_weather_city["sys"]["country"]
        cities_pd.loc[index, "Humidity"] = current_weather_city["main"]["humidity"]
        cities_pd.loc[index, "Date"] = current_weather_city["dt"]
        cities_pd.loc[index, "Lat"] = current_weather_city["coord"]["lat"]
        cities_pd.loc[index, "Lng"] = current_weather_city["coord"]["lon"]
        cities_pd.loc[index, "Max Temp"] = current_weather_city["main"]["temp_max"]
        cities_pd.loc[index, "Windspeed"] = current_weather_city["wind"]["speed"]
        print("_______________________________")
        
    except:
        print("Missing field/result... skipping.")
# Out:
# Processing for phalaborwa.
# _______________________________
# Processing for uyemskiy.
# _______________________________
# Processing for puerto ayora.
# _______________________________
# Processing for vaini.
# _______________________________
# Processing for tuktoyaktuk.
# _______________________________
# Processing for carnarvon.
# _______________________________
# Processing for riva.
# _______________________________
# Processing for cabo san lucas.
# _______________________________
# Processing for saint-philippe.
# _______________________________
# Processing for te anau.
# _______________________________
# Processing for norman wells.
# _______________________________
# Processing for arrecife.
# Missing field/result... skipping.
# Processing for luderitz.
# _______________________________
# Processing for pipri.
# _______________________________
# Processing for constitucion.
# _______________________________
# Processing for hermanus.
# _______________________________
# Processing for atuona.
# _______________________________
# Processing for mataura.
# _______________________________
# Processing for punta arenas.
# _______________________________
# Processing for sioux lookout.
# _______________________________
# Processing for dubbo.
# _______________________________
# Processing for thompson.
# _______________________________
# Processing for albany.
# _______________________________
# Processing for hilo.
# _______________________________
# Processing for sao joao da barra.
# _______________________________
# Processing for san patricio.
# _______________________________
# Processing for bredasdorp.
# _______________________________
# Processing for avarua.
# _______________________________
# Processing for bartica.
# _______________________________
# Processing for mapiri.
# _______________________________
# Processing for makakilo city.
# _______________________________
# Processing for selty.
# _______________________________
# Processing for bambous virieux.
# _______________________________
# Processing for khatanga.
# _______________________________
# Processing for portland.
# _______________________________
# Processing for busselton.
# _______________________________
# Processing for port moresby.
# _______________________________
# Processing for ushuaia.
# _______________________________
# Processing for tornio.
# _______________________________
# Processing for barrow.
# _______________________________
# Processing for victoria.
# _______________________________
# Processing for qaanaaq.
# _______________________________
# Processing for lebu.
# _______________________________
# Processing for kaitangata.
# _______________________________
# Processing for karkaralinsk.
# Missing field/result... skipping.
# Processing for tshane.
# _______________________________
# Processing for saint-pierre.
# _______________________________
# Processing for junin.
# _______________________________
# Processing for aswan.
# _______________________________
# Processing for butaritari.
# _______________________________
# Processing for nanchong.
# _______________________________
# Processing for kapit.
# _______________________________
# Processing for bluff.
# _______________________________
# Processing for sao filipe.
# _______________________________
# Processing for louisbourg.
# Missing field/result... skipping.
# Processing for port alfred.
# _______________________________
# Processing for barentsburg.
# Missing field/result... skipping.
# Processing for mount gambier.
# _______________________________
# Processing for taolanaro.
# Missing field/result... skipping.
# Processing for georgetown.
# _______________________________
# Processing for hami.
# _______________________________
# Processing for great yarmouth.
# _______________________________
# Processing for bonthe.
# _______________________________
# Processing for ondorhaan.
# Missing field/result... skipping.
# Processing for arraial do cabo.
# _______________________________
# Processing for athabasca.
# _______________________________
# Processing for east london.
# _______________________________
# Processing for tabas.
# _______________________________
# Processing for rikitea.
# _______________________________
# Processing for guerrero negro.
# _______________________________
# Processing for cape town.
# _______________________________
# Processing for khromtau.
# _______________________________
# Processing for new norfolk.
# _______________________________
# Processing for saskylakh.
# _______________________________
# Processing for half moon bay.
# _______________________________
# Processing for atar.
# _______________________________
# Processing for longyearbyen.
# _______________________________
# Processing for andenes.
# Missing field/result... skipping.
# Processing for adrar.
# _______________________________
# Processing for jacareacanga.
# _______________________________
# Processing for narsaq.
# _______________________________
# Processing for lavrentiya.
# _______________________________
# Processing for naze.
# _______________________________
# Processing for livingstone.
# _______________________________
# Processing for luebo.
# _______________________________
# Processing for hobart.
# _______________________________
# Processing for sibate.
# _______________________________
# Processing for saquena.
# _______________________________
# Processing for buraydah.
# _______________________________
# Processing for sangar.
# _______________________________
# Processing for sabaudia.
# _______________________________
# Processing for codrington.
# _______________________________
# Processing for nikolskoye.
# _______________________________
# Processing for presidencia roque saenz pena.
# _______________________________
# Processing for tasiilaq.
# _______________________________
# Processing for pevek.
# _______________________________
# Processing for necochea.
# _______________________________
# Processing for buchanan.
# _______________________________
# Processing for provideniya.
# _______________________________
# Processing for chokurdakh.
# _______________________________
# Processing for shakawe.
# _______________________________
# Processing for ribeira grande.
# _______________________________
# Processing for qaqortoq.
# _______________________________
# Processing for fort nelson.
# _______________________________
# Processing for palabuhanratu.
# Missing field/result... skipping.
# Processing for samusu.
# Missing field/result... skipping.
# Processing for valdosta.
# _______________________________
# Processing for gizo.
# _______________________________
# Processing for vilyuysk.
# _______________________________
# Processing for jinchang.
# _______________________________
# Processing for mbumi.
# _______________________________
# Processing for salalah.
# _______________________________
# Processing for port-gentil.
# _______________________________
# Processing for amderma.
# Missing field/result... skipping.
# Processing for torbay.
# _______________________________
# Processing for kingaroy.
# _______________________________
# Processing for illoqqortoormiut.
# Missing field/result... skipping.
# Processing for jiayuguan.
# _______________________________
# Processing for katsuura.
# _______________________________
# Processing for rocha.
# _______________________________
# Processing for parana.
# _______________________________
# Processing for saint-francois.
# _______________________________
# Processing for bosaso.
# _______________________________
# Processing for asgabat.
# Missing field/result... skipping.
# Processing for tumannyy.
# Missing field/result... skipping.
# Processing for douentza.
# _______________________________
# Processing for uppsala.
# _______________________________
# Processing for port elizabeth.
# _______________________________
# Processing for beringovskiy.
# _______________________________
# Processing for kassala.
# _______________________________
# Processing for airai.
# _______________________________
# Processing for karamay.
# Missing field/result... skipping.
# Processing for zirc.
# _______________________________
# Processing for kinablangan.
# _______________________________
# Processing for hun.
# _______________________________
# Processing for borogontsy.
# _______________________________
# Processing for leh.
# _______________________________
# Processing for nanortalik.
# _______________________________
# Processing for los llanos de aridane.
# _______________________________
# Processing for san cristobal.
# _______________________________
# Processing for huilong.
# _______________________________
# Processing for ayan.
# _______________________________
# Processing for castro.
# _______________________________
# Processing for vaitupu.
# Missing field/result... skipping.
# Processing for chagda.
# Missing field/result... skipping.
# Processing for cherskiy.
# _______________________________
# Processing for broome.
# _______________________________
# Processing for muzhi.
# _______________________________
# Processing for mar del plata.
# _______________________________
# Processing for nome.
# _______________________________
# Processing for zhigansk.
# _______________________________
# Processing for kapaa.
# _______________________________
# Processing for kodiak.
# _______________________________
# Processing for lake cowichan.
# _______________________________
# Processing for ambodifototra.
# Missing field/result... skipping.
# Processing for jamestown.
# _______________________________
# Processing for belushya guba.
# Missing field/result... skipping.
# Processing for hasaki.
# _______________________________
# Processing for bengkulu.
# Missing field/result... skipping.
# Processing for boysun.
# _______________________________
# Processing for yellowknife.
# _______________________________
# Processing for reading.
# _______________________________
# Processing for pangnirtung.
# _______________________________
# Processing for sarapul.
# _______________________________
# Processing for karratha.
# _______________________________
# Processing for umm lajj.
# _______________________________
# Processing for matadi.
# _______________________________
# Processing for hualmay.
# _______________________________
# Processing for udachnyy.
# _______________________________
# Processing for omaruru.
# _______________________________
# Processing for gulshat.
# Missing field/result... skipping.
# Processing for esperance.
# _______________________________
# Processing for taikang.
# _______________________________
# Processing for nyurba.
# _______________________________
# Processing for aklavik.
# _______________________________
# Processing for chingirlau.
# _______________________________
# Processing for puerto madero.
# _______________________________
# Processing for chuy.
# _______________________________
# Processing for bethel.
# _______________________________
# Processing for ostrovnoy.
# _______________________________
# Processing for porto velho.
# _______________________________
# Processing for lucea.
# _______________________________
# Processing for chopinzinho.
# _______________________________
# Processing for tiksi.
# _______________________________
# Processing for dingle.
# _______________________________
# Processing for hamilton.
# _______________________________
# Processing for havelock.
# _______________________________
# Processing for leo.
# _______________________________
# Processing for suhum.
# _______________________________
# Processing for davidson.
# _______________________________
# Processing for road town.
# _______________________________
# Processing for cholula.
# _______________________________
# Processing for mecca.
# _______________________________
# Processing for junction city.
# _______________________________
# Processing for bereda.
# _______________________________
# Processing for vao.
# _______________________________
# Processing for sinnamary.
# _______________________________
# Processing for sentyabrskiy.
# Missing field/result... skipping.
# Processing for severo-kurilsk.
# _______________________________
# Processing for olinda.
# _______________________________
# Processing for tymovskoye.
# _______________________________
# Processing for nizhneyansk.
# Missing field/result... skipping.
# Processing for agirish.
# _______________________________
# Processing for oktyabrskiy.
# _______________________________
# Processing for baie-comeau.
# _______________________________
# Processing for lorengau.
# _______________________________
# Processing for mahebourg.
# _______________________________
# Processing for upernavik.
# _______________________________
# Processing for attawapiskat.
# Missing field/result... skipping.
# Processing for westlock.
# _______________________________
# Processing for aksu.
# _______________________________
# Processing for tofield.
# _______________________________
# Processing for san policarpo.
# _______________________________
# Processing for ancud.
# _______________________________
# Processing for mandurah.
# _______________________________
# Processing for gazanjyk.
# _______________________________
# Processing for touros.
# _______________________________
# Processing for acapulco.
# _______________________________
# Processing for chumikan.
# _______________________________
# Processing for paradwip.
# Missing field/result... skipping.
# Processing for talnakh.
# _______________________________
# Processing for lagoa.
# _______________________________
# Processing for prince rupert.
# _______________________________
# Processing for rawannawi.
# Missing field/result... skipping.
# Processing for marsh harbour.
# _______________________________
# Processing for dikson.
# _______________________________
# Processing for blytheville.
# _______________________________
# Processing for maxixe.
# _______________________________
# Processing for kruisfontein.
# _______________________________
# Processing for whitehorse.
# _______________________________
# Processing for olga.
# _______________________________
# Processing for umarkhed.
# _______________________________
# Processing for leningradskiy.
# _______________________________
# Processing for rivadavia.
# _______________________________
# Processing for yirol.
# Missing field/result... skipping.
# Processing for batemans bay.
# _______________________________
# Processing for chadiza.
# _______________________________
# Processing for belyy yar.
# _______________________________
# Processing for tilichiki.
# _______________________________
# Processing for matara.
# _______________________________
# Processing for tutoia.
# _______________________________
# Processing for campbell river.
# _______________________________
# Processing for port lincoln.
# _______________________________
# Processing for garissa.
# _______________________________
# Processing for baghdad.
# _______________________________
# Processing for clyde river.
# _______________________________
# Processing for honningsvag.
# _______________________________
# Processing for raahe.
# _______________________________
# Processing for lodja.
# _______________________________
# Processing for belmonte.
# _______________________________
# Processing for pali.
# _______________________________
# Processing for cidreira.
# _______________________________
# Processing for hithadhoo.
# _______________________________
# Processing for harrison.
# _______________________________
# Processing for souillac.
# _______________________________
# Processing for ndioum.
# _______________________________
# Processing for saint george.
# _______________________________
# Processing for tuy hoa.
# _______________________________
# Processing for challans.
# _______________________________
# Processing for zyryanka.
# _______________________________
# Processing for dudinka.
# _______________________________
# Processing for ondangwa.
# _______________________________
# Processing for shimoda.
# _______________________________
# Processing for vozhega.
# _______________________________
# Processing for farafangana.
# _______________________________
# Processing for olafsvik.
# Missing field/result... skipping.
# Processing for kirakira.
# _______________________________
# Processing for sisimiut.
# _______________________________
# Processing for jijiga.
# _______________________________
# Processing for bambanglipuro.
# _______________________________
# Processing for eyl.
# _______________________________
# Processing for ouargaye.
# _______________________________
# Processing for urucara.
# _______________________________
# Processing for alyangula.
# _______________________________
# Processing for faanui.
# _______________________________
# Processing for ewo.
# _______________________________
# Processing for deputatskiy.
# _______________________________
# Processing for auburn.
# _______________________________
# Processing for gorom-gorom.
# _______________________________
# Processing for fortuna.
# _______________________________
# Processing for bandarbeyla.
# _______________________________
# Processing for fort saint james.
# _______________________________
# Processing for plouzane.
# _______________________________
# Processing for samalaeulu.
# Missing field/result... skipping.
# Processing for komsomolskiy.
# _______________________________
# Processing for dwarka.
# _______________________________
# Processing for taldan.
# _______________________________
# Processing for la ronge.
# _______________________________
# Processing for viligili.
# Missing field/result... skipping.
# Processing for harper.
# _______________________________
# Processing for huanren.
# _______________________________
# Processing for flinders.
# _______________________________
# Processing for ucluelet.
# _______________________________
# Processing for alta floresta.
# _______________________________
# Processing for margate.
# _______________________________
# Processing for saleaula.
# Missing field/result... skipping.
# Processing for skole.
# _______________________________
# Processing for boa vista.
# _______________________________
# Processing for goderich.
# _______________________________
# Processing for gornopravdinsk.
# _______________________________
# Processing for westport.
# _______________________________
# Processing for pacific grove.
# _______________________________
# Processing for barzas.
# _______________________________
# Processing for woodstock.
# _______________________________
# Processing for ambovombe.
# _______________________________
# Processing for rawson.
# _______________________________
# Processing for mendahara.
# Missing field/result... skipping.
# Processing for maturin.
# _______________________________
# Processing for millinocket.
# _______________________________
# Processing for malakal.
# Missing field/result... skipping.
# Processing for vila franca do campo.
# _______________________________
# Processing for orbetello.
# _______________________________
# Processing for kahului.
# _______________________________
# Processing for khuzdar.
# _______________________________
# Processing for north bend.
# _______________________________
# Processing for port keats.
# _______________________________
# Processing for sambava.
# _______________________________
# Processing for marcona.
# Missing field/result... skipping.
# Processing for asfi.
# Missing field/result... skipping.
# Processing for saint anthony.
# _______________________________
# Processing for benque viejo.
# Missing field/result... skipping.
# Processing for huarmey.
# _______________________________
# Processing for arzgir.
# _______________________________
# Processing for puerto escondido.
# _______________________________
# Processing for wewak.
# _______________________________
# Processing for dekoa.
# Missing field/result... skipping.
# Processing for nhulunbuy.
# _______________________________
# Processing for cedar city.
# _______________________________
# Processing for emerald.
# _______________________________
# Processing for kavieng.
# _______________________________
# Processing for itaituba.
# _______________________________
# Processing for sovetskaya.
# _______________________________
# Processing for hope.
# _______________________________
# Processing for hofn.
# _______________________________
# Processing for mount isa.
# _______________________________
# Processing for ananas.
# _______________________________
# Processing for baruun-urt.
# _______________________________
# Processing for magadan.
# _______________________________
# Processing for tsihombe.
# Missing field/result... skipping.
# Processing for pocone.
# _______________________________
# Processing for kasongo-lunda.
# _______________________________
# Processing for araxa.
# _______________________________
# Processing for upington.
# _______________________________
# Processing for yar-sale.
# _______________________________
# Processing for bokspits.
# Missing field/result... skipping.
# Processing for caravelas.
# _______________________________
# Processing for peabiru.
# _______________________________
# Processing for mys shmidta.
# Missing field/result... skipping.
# Processing for nelson bay.
# _______________________________
# Processing for udayagiri.
# _______________________________
# Processing for villa guerrero.
# _______________________________
# Processing for kudahuvadhoo.
# _______________________________
# Processing for trat.
# _______________________________
# Processing for vardo.
# _______________________________
# Processing for ariquemes.
# _______________________________
# Processing for manokwari.
# _______________________________
# Processing for babu.
# _______________________________
# Processing for zemio.
# _______________________________
# Processing for faya.
# _______________________________
# Processing for bara.
# _______________________________
# Processing for lima.
# _______________________________
# Processing for saquarema.
# _______________________________
# Processing for cockburn town.
# _______________________________
# Processing for severomuysk.
# _______________________________
# Processing for iqaluit.
# _______________________________
# Processing for tecolutla.
# _______________________________
# Processing for ilulissat.
# _______________________________
# Processing for kotido.
# _______________________________
# Processing for santiago del estero.
# _______________________________
# Processing for skowhegan.
# _______________________________
# Processing for qandahar.
# Missing field/result... skipping.
# Processing for grand river south east.
# Missing field/result... skipping.
# Processing for rio gallegos.
# _______________________________
# Processing for nantucket.
# _______________________________
# Processing for ketchikan.
# _______________________________
# Processing for geraldton.
# _______________________________
# Processing for boo.
# _______________________________
# Processing for tabou.
# _______________________________
# Processing for xai-xai.
# _______________________________
# Processing for puerto colombia.
# _______________________________
# Processing for ornskoldsvik.
# _______________________________
# Processing for coahuayana.
# _______________________________
# Processing for alice springs.
# _______________________________
# Processing for kolokani.
# _______________________________
# Processing for yulara.
# _______________________________
# Processing for nouadhibou.
# _______________________________
# Processing for iquitos.
# _______________________________
# Processing for alofi.
# _______________________________
# Processing for raudeberg.
# _______________________________
# Processing for coracao de jesus.
# _______________________________
# Processing for dongsheng.
# _______________________________
# Processing for tabuk.
# _______________________________
# Processing for umzimvubu.
# Missing field/result... skipping.
# Processing for kasulu.
# _______________________________
# Processing for sibiti.
# _______________________________
# Processing for broomall.
# _______________________________
# Processing for bitung.
# _______________________________
# Processing for vila velha.
# _______________________________
# Processing for bargal.
# Missing field/result... skipping.
# Processing for henties bay.
# _______________________________
# Processing for college.
# _______________________________
# Processing for progreso.
# _______________________________
# Processing for ahipara.
# _______________________________
# Processing for evensk.
# _______________________________
# Processing for quatre cocos.
# _______________________________
# Processing for sile.
# _______________________________
# Processing for riyadh.
# _______________________________
# Processing for heinola.
# _______________________________
# Processing for quelimane.
# _______________________________
# Processing for gazojak.
# _______________________________
# Processing for grindavik.
# _______________________________
# Processing for brae.
# _______________________________
# Processing for lubao.
# _______________________________
# Processing for kurdzhinovo.
# _______________________________
# Processing for saint-augustin.
# _______________________________
# Processing for vestmannaeyjar.
# _______________________________
# Processing for tahoua.
# _______________________________
# Processing for tecate.
# _______________________________
# Processing for mandalgovi.
# _______________________________
# Processing for erseke.
# _______________________________
# Processing for mahon.
# _______________________________
# Processing for barcelos.
# _______________________________
# Processing for yizheng.
# _______________________________
# Processing for kokopo.
# _______________________________
# Processing for beloha.
# _______________________________
# Processing for san carlos.
# _______________________________
# Processing for pemberton.
# _______________________________
# Processing for lukovetskiy.
# _______________________________
# Processing for lata.
# _______________________________
# Processing for ravar.
# _______________________________
# Processing for lajeado.
# _______________________________
# Processing for ishigaki.
# _______________________________
# Processing for san vicente.
# _______________________________
# Processing for sharya.
# _______________________________
# Processing for porto novo.
# _______________________________
# Processing for sawakin.
# _______________________________
# Processing for chicama.
# _______________________________
# Processing for tapaua.
# Missing field/result... skipping.
# Processing for hare bay.
# _______________________________
# Processing for namibe.
# _______________________________
# Processing for axim.
# _______________________________
# Processing for comodoro rivadavia.
# _______________________________
# Processing for madera.
# _______________________________
# Processing for ponta do sol.
# _______________________________
# Processing for ust-ishim.
# _______________________________
# Processing for manama.
# _______________________________
# Processing for muhos.
# _______________________________
# Processing for bontang.
# _______________________________
# Processing for ileza.
# _______________________________
# Processing for babanusah.
# Missing field/result... skipping.
# Processing for salas.
# _______________________________
# Processing for vysokogornyy.
# _______________________________
# Processing for makushino.
# _______________________________
# Processing for havre-saint-pierre.
# _______________________________
# Processing for pakwach.
# Missing field/result... skipping.
# Processing for sabang.
# _______________________________
# Processing for conceicao do araguaia.
# _______________________________
# Processing for dvorichna.
# _______________________________
# Processing for sorong.
# _______________________________
# Processing for san rafael del sur.
# _______________________________
# Processing for melendugno.
# _______________________________
# Processing for brigantine.
# _______________________________
# Processing for kabinda.
# _______________________________
# Processing for evanston.
# _______________________________
# Processing for rio grande.
# _______________________________
# Processing for tautira.
# _______________________________
# Processing for tafresh.
# _______________________________
# Processing for angoche.
# _______________________________
# Processing for tabukiniberu.
# Missing field/result... skipping.
# Processing for viedma.
# _______________________________
# Processing for murmashi.
# _______________________________
# Processing for ternate.
# _______________________________
# Processing for shelburne.
# _______________________________
# Processing for cabangahan.
# _______________________________
# Processing for warrington.
# _______________________________
# Processing for batagay.
# _______________________________
# Processing for kachiry.
# _______________________________
# Processing for zalantun.
# _______________________________
# Processing for arcachon.
# _______________________________
# Processing for bud.
# _______________________________
# Processing for nizwa.
# _______________________________
# Processing for skalistyy.
# Missing field/result... skipping.
# Processing for daru.
# _______________________________
# Processing for dolores hidalgo.
# _______________________________
# Processing for samarina.
# _______________________________
# Processing for awbari.
# _______________________________
# Processing for katha.
# Missing field/result... skipping.
# Processing for tupik.
# _______________________________
# Processing for stenlille.
# _______________________________
# Processing for taoudenni.
# _______________________________
# Processing for skelleftea.
# _______________________________
# Processing for nova vicosa.
# _______________________________
# Processing for bellefontaine.
# _______________________________
# Processing for mitchell.
# _______________________________
# Processing for nishihara.
# _______________________________
# Processing for nchelenge.
# _______________________________
# Processing for batouri.
# _______________________________
# Processing for dunedin.
# _______________________________
# Processing for gat.
# _______________________________
# Processing for coihaique.
# _______________________________
# Processing for chimbote.
# _______________________________
# Processing for magura.
# _______________________________
# Processing for carman.
# _______________________________
# Processing for mbarara.
# _______________________________
# Processing for kendari.
# _______________________________
# Processing for shellbrook.
# _______________________________
# Processing for bafoulabe.
# _______________________________
# Processing for roza.
# _______________________________
# Processing for pueblo.
# _______________________________
# Processing for kontagora.
# _______________________________
# Processing for sao borja.
# _______________________________
# Processing for marystown.
# _______________________________
# Processing for yangcun.
# _______________________________
# Processing for buala.
# _______________________________
# Processing for lolua.
# Missing field/result... skipping.
# Processing for bilma.
# _______________________________
# Processing for mehamn.
# _______________________________
# Processing for baikunthpur.
# _______________________________
# Processing for dickinson.
# _______________________________
# Processing for molina.
# _______________________________
# Processing for akyab.
# Missing field/result... skipping.
# Processing for southbridge.
# _______________________________
# Processing for sao miguel do araguaia.
# _______________________________
# Processing for atasu.
# _______________________________
# Processing for novo oriente.
# _______________________________
# Processing for pryazha.
# _______________________________
# Processing for oshnaviyeh.
# _______________________________
# Processing for tshikapa.
# _______________________________
# Processing for lincoln.
# _______________________________
# Processing for elko.
# _______________________________
# Processing for fare.
# _______________________________
# Processing for kawalu.
# _______________________________
# Processing for porirua.
# _______________________________
# Processing for kitimat.
# _______________________________
# Processing for safaga.
# Missing field/result... skipping.
# Processing for ambilobe.
# _______________________________
# Processing for pisco.
# _______________________________
# Processing for todos santos.
# _______________________________
# Processing for bolungarvik.
# Missing field/result... skipping.
# Processing for dzhusaly.
# Missing field/result... skipping.
# Processing for solnechnyy.
# _______________________________
# Processing for forbes.
# _______________________________
# Processing for bakel.
# _______________________________
# Processing for ust-ilimsk.
# _______________________________
# Processing for carai.
# _______________________________
# Processing for mosquera.
# _______________________________
# Processing for alghero.
# _______________________________
# Processing for masumbwe.
# _______________________________
# Processing for muroto.
# _______________________________
# Processing for lowestoft.
# _______________________________
# Processing for gotsu.
# _______________________________
# Processing for dolbeau.
# Missing field/result... skipping.
# Processing for miri.
# _______________________________
# Processing for karamken.
# Missing field/result... skipping.
# Processing for belgrade.
# _______________________________
# Processing for rafai.
# _______________________________
# Processing for buariki.
# Missing field/result... skipping.
# Processing for beian.
# _______________________________
# Processing for kloulklubed.
# _______________________________
# Processing for shebalino.
# _______________________________
# Processing for lembeni.
# _______________________________
# Processing for sola.
# _______________________________
# Processing for talaya.
# _______________________________
# Processing for juli.
# _______________________________
# Processing for krasnoarmeysk.
# _______________________________
# Processing for litovko.
# _______________________________
# Processing for bonavista.
# _______________________________
# Processing for shenjiamen.
# _______________________________
# Processing for itaqui.
# _______________________________
# Processing for qui nhon.
# Missing field/result... skipping.
# Processing for vila do maio.
# _______________________________
# Processing for tingrela.
# Missing field/result... skipping.
# Processing for hailey.
# _______________________________
# Processing for qinzhou.
# _______________________________
# Processing for petauke.
# _______________________________
# Processing for ramsar.
# _______________________________
# Processing for labuhan.
# _______________________________
# Processing for barranca.
# _______________________________
# Processing for lakes entrance.
# _______________________________
# Processing for tura.
# _______________________________
# Processing for sungaipenuh.
# _______________________________
# Processing for limon.
# _______________________________
# Processing for burns lake.
# _______________________________
# Processing for vrangel.
# _______________________________
# Processing for kota bahru.
# Missing field/result... skipping.
# Processing for tahe.
# _______________________________
# Processing for burley.
# _______________________________
# Processing for khorinsk.
# _______________________________
# Processing for yangjiang.
# _______________________________
# Processing for koungou.
# Missing field/result... skipping.
# Processing for homer.
# _______________________________
# Processing for chaihe.
# _______________________________
# Processing for inuvik.
# _______________________________
# Processing for cap malheureux.
# _______________________________
# Processing for varenikovskaya.
# _______________________________
# Processing for praya.
# _______________________________
# Processing for hihifo.
# Missing field/result... skipping.
# Processing for klichka.
# _______________________________
# Processing for los algarrobos.
# _______________________________
# Processing for vinh.
# _______________________________
# Processing for salym.
# _______________________________
# Processing for bur gabo.
# Missing field/result... skipping.
# Processing for palembang.
# _______________________________
# Processing for avera.
# _______________________________
# Processing for medvedok.
# _______________________________
# Processing for okhotsk.
# _______________________________
# Processing for lahaina.
# _______________________________
# Processing for suda.
# _______________________________
# Processing for dzerzhinskoye.
# _______________________________
# Processing for smithers.
# _______________________________
# Processing for magomeni.
# _______________________________
# Processing for ulaanbaatar.
# _______________________________
# Processing for trujillo.
# _______________________________
# Processing for pandan.
# _______________________________
# Processing for ust-kulom.
# _______________________________
# Processing for neiafu.
# _______________________________

# %%
cities_pd = cities_pd.dropna(how='any')
cities_pd["Max Temp"] = pd.to_numeric(cities_pd["Max Temp"])
cities_pd["Lat"] = pd.to_numeric(cities_pd["Lat"])
cities_pd["Lng"] = pd.to_numeric(cities_pd["Lng"])
cities_pd["Cloudiness"] = pd.to_numeric(cities_pd["Cloudiness"])
cities_pd["Humidity"] = pd.to_numeric(cities_pd["Humidity"])
cities_pd["Windspeed"] = pd.to_numeric(cities_pd["Windspeed"])
print(len(cities_pd))
cities_pd.dtypes
# Out:
# 553
# City           object
# Cloudiness    float64
# Country        object
# Humidity      float64
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Windspeed     float64
# dtype: object

# %%
cities_pd.head(35)
# Out:
#                  City  Cloudiness Country  Humidity        Date    Lat  \
# 0          phalaborwa        52.0      ZA      94.0  1576111102 -23.95
# 1            uyemskiy        75.0      RU      73.0  1576111209  64.47
# 2        puerto ayora        20.0      EC      65.0  1576111209  -0.74
# 3               vaini         2.0      IN      93.0  1576111209  15.34
# 4         tuktoyaktuk         5.0      CA      69.0  1576111210  69.44
# 5           carnarvon         0.0      ZA      41.0  1576111210 -30.97
# 6                riva        75.0      ES      87.0  1576111211  43.28
# 7      cabo san lucas        40.0      MX      68.0  1576110976  22.89
# 8      saint-philippe        75.0      CA      63.0  1576111211  45.36
# 9             te anau        89.0      NZ      93.0  1576111211 -45.41
# 10       norman wells         5.0      CA      75.0  1576111211  65.28
# 12           luderitz         0.0      NA      93.0  1576111211 -26.65
# 13              pipri        94.0      IN      73.0  1576111211  24.21
# 14       constitucion         5.0      MX      25.0  1576111211  23.99
# 15           hermanus        14.0      ZA      81.0  1576111211 -34.42
# 16             atuona        76.0      PF      69.0  1576111211  -9.80
# 17            mataura       100.0      NZ      52.0  1576111211 -46.19
# 18       punta arenas        75.0      CL      57.0  1576111211 -53.16
# 19      sioux lookout         5.0      CA      69.0  1576111211  50.10
# 20              dubbo        40.0      AU      23.0  1576111211 -32.25
# 21           thompson         5.0      CA      74.0  1576111211  55.74
# 22             albany        75.0      US      87.0  1576111211  42.65
# 23               hilo        75.0      US      69.0  1576111211  19.71
# 24  sao joao da barra       100.0      BR      90.0  1576110930 -21.64
# 25       san patricio         0.0      PY      48.0  1576111212 -26.98
# 26         bredasdorp        42.0      ZA      82.0  1576111212 -34.53
# 27             avarua        82.0      CK      83.0  1576111212 -21.21
# 28            bartica        90.0      GY     100.0  1576111212   6.41
# 29             mapiri       100.0      BO      97.0  1576111212 -15.31
# 30      makakilo city         1.0      US      66.0  1576111212  21.35
# 31              selty        81.0      RU      85.0  1576111212  57.31
# 32    bambous virieux        40.0      MU      88.0  1576111212 -20.34
# 33           khatanga       100.0      RU      88.0  1576111212  71.98
# 34           portland         1.0      US      73.0  1576111188  43.66
# 35          busselton        16.0      AU      24.0  1576111212 -33.64
#
#        Lng  Max Temp  Windspeed
# 0    31.14     22.00       1.50
# 1    40.85     -3.00       4.00
# 2   -90.35     25.00       7.70
# 3    74.49     16.00       1.26
# 4  -133.03    -25.00       7.70
# 5    22.13     18.10       5.90
# 6    -3.56     12.78       7.20
# 7  -109.91     23.33       2.10
# 8   -73.48     -3.00       9.80
# 9   167.72     12.71       2.41
# 10 -126.83    -26.00       4.10
# 12   15.16     16.00       4.60
# 13   83.02     12.92       2.11
# 14 -104.67     19.00       1.00
# 15   19.24     19.44       3.58
# 16 -139.03     26.40       5.82
# 17  168.86     22.58       1.60
# 18  -70.91     11.00      10.80
# 19  -91.92    -21.00       2.60
# 20  148.60     28.00       4.60
# 21  -97.86    -31.00       1.50
# 22  -73.75      0.00       2.60
# 23 -155.08     27.00       5.70
# 24  -41.05     24.18       7.87
# 25  -56.83     26.54       1.52
# 26   20.04     19.44       5.70
# 27 -159.78     27.00       7.20
# 28  -58.62     24.00       2.10
# 29  -68.22     20.58       0.38
# 30 -158.09     29.00       4.10
# 31   52.14     -6.58       4.11
# 32   57.76     26.67       0.50
# 33  102.47    -22.62       3.92
# 34  -70.25     -2.78       2.10
# 35  115.35     28.33       5.76

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
#### Latitude vs. Temperature Plot
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Max Temp"]
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Temperature (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.show()

# %%
#Bonus Visualization: Bivariate chart with added hue for longitude   
exp.plot_bivariate(cities_pd, 'Lat', 'Max Temp', hue='Lng', alpha=1.0)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Humidity"]
colors = ("green")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Humidity (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %%
#Bonus Visualization: Bivariate chart with added hue for longitude   
exp.plot_bivariate(cities_pd, 'Lat', 'Humidity', hue='Lng', alpha=1.0)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Cloudiness"]
colors = ("red")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Cloudiness (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %%
#Bonus Visualization: Bivariate chart with added hue for longitude   
exp.plot_bivariate(cities_pd, 'Lat', 'Cloudiness', hue='Lng', alpha=1.0)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Windspeed"]
colors = ("brown")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Windspeed (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %%
#Bonus Visualization: Bivariate chart with added hue for longitude   
exp.plot_bivariate(cities_pd, 'Lat', 'Windspeed', hue='Lng', alpha=1.0)
