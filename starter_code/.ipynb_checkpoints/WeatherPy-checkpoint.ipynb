# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
import openweathermapy as ow

# Import API key
#from api_keys import api_key


#config
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-30.000, high=30.000, size=1500)
lngs = np.random.uniform(low=-15.000, high=15.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 277

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Import cities as DataFrame
column_names = ["City"]
cities_pd = pd.DataFrame(cities, columns=column_names)
cities_pd["Cloudiness"] = ""
cities_pd["Country"] = ""
cities_pd["Humidity"] = ""
cities_pd["Date"] = ""
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Max Temp"] = ""
cities_pd["Windspeed"] = ""
cities_pd.head()
# Out:
#          City Cloudiness Country Humidity Date Lat Lng Max Temp Windspeed
# 0       bilma
# 1  georgetown
# 2       gusau
# 3   taoudenni
# 4        lere

# %%
for index, row in cities_pd.iterrows():
    # get name from df
    name = row["City"]
    try:
        print(f"Processing for {name}.")
        current_weather_city = owm.get_current(name, **settings)
        cities_pd.loc[index, "Cloudiness"] = current_weather_city["clouds"]["all"]
        cities_pd.loc[index, "Country"] = current_weather_city["sys"]["country"]
        cities_pd.loc[index, "Humidity"] = current_weather_city["main"]["humidity"]
        cities_pd.loc[index, "Date"] = current_weather_city["dt"]
        cities_pd.loc[index, "Lat"] = current_weather_city["coord"]["lat"]
        cities_pd.loc[index, "Lng"] = current_weather_city["coord"]["lon"]
        cities_pd.loc[index, "Max Temp"] = current_weather_city["main"]["temp_max"]
        cities_pd.loc[index, "Windspeed"] = current_weather_city["wind"]["speed"]
        print("_______________________________")
        
    except:
        print("Missing field/result... skipping.")
# Out:
# Processing for bilma.
# _______________________________
# Processing for georgetown.
# _______________________________
# Processing for gusau.
# _______________________________
# Processing for taoudenni.
# _______________________________
# Processing for lere.
# _______________________________
# Processing for atar.
# _______________________________
# Processing for kidal.
# _______________________________
# Processing for maghama.
# Missing field/result... skipping.
# Processing for epe.
# _______________________________
# Processing for gat.
# _______________________________
# Processing for djibo.
# _______________________________
# Processing for agadez.
# _______________________________
# Processing for port-gentil.
# _______________________________
# Processing for jamestown.
# _______________________________
# Processing for tahoua.
# _______________________________
# Processing for henties bay.
# _______________________________
# Processing for ogaminana.
# _______________________________
# Processing for luba.
# _______________________________
# Processing for soubre.
# _______________________________
# Processing for axim.
# _______________________________
# Processing for luanda.
# _______________________________
# Processing for harper.
# _______________________________
# Processing for luderitz.
# _______________________________
# Processing for namibe.
# _______________________________
# Processing for tabou.
# _______________________________
# Processing for tessalit.
# _______________________________
# Processing for walvis bay.
# _______________________________
# Processing for mayumba.
# _______________________________
# Processing for marrakesh.
# _______________________________
# Processing for bertoua.
# _______________________________
# Processing for tiznit.
# _______________________________
# Processing for markala.
# _______________________________
# Processing for monrovia.
# _______________________________
# Processing for bitam.
# _______________________________
# Processing for kolondieba.
# _______________________________
# Processing for caxito.
# _______________________________
# Processing for ongandjera.
# _______________________________
# Processing for warqla.
# Missing field/result... skipping.
# Processing for tombouctou.
# _______________________________
# Processing for gamba.
# _______________________________
# Processing for biu.
# _______________________________
# Processing for omboue.
# _______________________________
# Processing for tchaourou.
# _______________________________
# Processing for benguela.
# _______________________________
# Processing for soyo.
# _______________________________
# Processing for caluquembe.
# _______________________________
# Processing for mbanza-ngungu.
# _______________________________
# Processing for aguimes.
# _______________________________
# Processing for yenagoa.
# _______________________________
# Processing for nouakchott.
# _______________________________
# Processing for san.
# _______________________________
# Processing for ughelli.
# _______________________________
# Processing for diapaga.
# _______________________________
# Processing for anloga.
# _______________________________
# Processing for diffa.
# _______________________________
# Processing for zaria.
# _______________________________
# Processing for bababe.
# Missing field/result... skipping.
# Processing for adrar.
# _______________________________
# Processing for puerto del rosario.
# _______________________________
# Processing for kolokani.
# _______________________________
# Processing for natitingou.
# _______________________________
# Processing for oranjemund.
# _______________________________
# Processing for kano.
# _______________________________
# Processing for kaura namoda.
# _______________________________
# Processing for tsogni.
# _______________________________
# Processing for warri.
# _______________________________
# Processing for tarudant.
# Missing field/result... skipping.
# Processing for abalak.
# _______________________________
# Processing for goderich.
# _______________________________
# Processing for sangueya.
# _______________________________
# Processing for dutse.
# _______________________________
# Processing for tchollire.
# _______________________________
# Processing for yokadouma.
# _______________________________
# Processing for grand-lahou.
# _______________________________
# Processing for sokoto.
# _______________________________
# Processing for nioro.
# _______________________________
# Processing for teguise.
# _______________________________
# Processing for awbari.
# _______________________________
# Processing for keffi.
# _______________________________
# Processing for kanel.
# _______________________________
# Processing for marzuq.
# _______________________________
# Processing for jacqueville.
# _______________________________
# Processing for djambala.
# _______________________________
# Processing for katsina.
# _______________________________
# Processing for ikom.
# _______________________________
# Processing for araouane.
# _______________________________
# Processing for okandja.
# Missing field/result... skipping.
# Processing for ayorou.
# _______________________________
# Processing for arlit.
# _______________________________
# Processing for mumford.
# _______________________________
# Processing for lubango.
# _______________________________
# Processing for mao.
# _______________________________
# Processing for ejura.
# _______________________________
# Processing for malumfashi.
# _______________________________
# Processing for mongomo.
# _______________________________
# Processing for opuwo.
# _______________________________
# Processing for cotonou.
# _______________________________
# Processing for ndiekro.
# Missing field/result... skipping.
# Processing for bonthe.
# _______________________________
# Processing for guider.
# _______________________________
# Processing for bassar.
# _______________________________
# Processing for nguru.
# _______________________________
# Processing for goundam.
# _______________________________
# Processing for gouloure.
# _______________________________
# Processing for ketou.
# _______________________________
# Processing for mitzic.
# _______________________________
# Processing for makokou.
# _______________________________
# Processing for garoua boulai.
# _______________________________
# Processing for matadi.
# _______________________________
# Processing for abong mbang.
# _______________________________
# Processing for nikki.
# _______________________________
# Processing for takoradi.
# _______________________________
# Processing for birnin kebbi.
# _______________________________
# Processing for bamako.
# _______________________________
# Processing for numan.
# _______________________________
# Processing for berekum.
# _______________________________
# Processing for sibiti.
# _______________________________
# Processing for kerouane.
# _______________________________
# Processing for sassandra.
# _______________________________
# Processing for adzope.
# _______________________________
# Processing for maiduguri.
# _______________________________
# Processing for jos.
# _______________________________
# Processing for azare.
# _______________________________
# Processing for bingerville.
# _______________________________
# Processing for lagos.
# _______________________________
# Processing for gao.
# _______________________________
# Processing for riaba.
# Missing field/result... skipping.
# Processing for conakry.
# _______________________________
# Processing for kayes.
# _______________________________
# Processing for save.
# _______________________________
# Processing for bindi.
# _______________________________
# Processing for bakel.
# _______________________________
# Processing for dinguiraye.
# _______________________________
# Processing for mbalmayo.
# _______________________________
# Processing for ewo.
# _______________________________
# Processing for mattru.
# _______________________________
# Processing for oyem.
# _______________________________
# Processing for batouri.
# _______________________________
# Processing for abidjan.
# _______________________________
# Processing for ndjole.
# _______________________________
# Processing for tubmanburg.
# _______________________________
# Processing for potiskum.
# _______________________________
# Processing for bibiani.
# _______________________________
# Processing for kibala.
# _______________________________
# Processing for las palmas.
# _______________________________
# Processing for nzerekore.
# _______________________________
# Processing for sumbe.
# _______________________________
# Processing for bobo dioulasso.
# Missing field/result... skipping.
# Processing for ouahigouya.
# _______________________________
# Processing for lokoja.
# _______________________________
# Processing for tias.
# _______________________________
# Processing for manga.
# _______________________________
# Processing for kedougou.
# _______________________________
# Processing for damaturu.
# _______________________________
# Processing for kishi.
# _______________________________
# Processing for lafia.
# _______________________________
# Processing for tingrela.
# Missing field/result... skipping.
# Processing for dori.
# _______________________________
# Processing for funtua.
# _______________________________
# Processing for robertsport.
# _______________________________
# Processing for jalingo.
# _______________________________
# Processing for zwedru.
# _______________________________
# Processing for mossendjo.
# _______________________________
# Processing for tanout.
# _______________________________
# Processing for ode.
# _______________________________
# Processing for hadejia.
# _______________________________
# Processing for gayeri.
# _______________________________
# Processing for maine-soroa.
# _______________________________
# Processing for jega.
# _______________________________
# Processing for gaoua.
# _______________________________
# Processing for tenenkou.
# _______________________________
# Processing for pala.
# _______________________________
# Processing for nalut.
# _______________________________
# Processing for tessaoua.
# _______________________________
# Processing for buchanan.
# _______________________________
# Processing for tema.
# _______________________________
# Processing for mpraeso.
# _______________________________
# Processing for kousseri.
# Missing field/result... skipping.
# Processing for douentza.
# _______________________________
# Processing for koungheul.
# _______________________________
# Processing for lungi.
# _______________________________
# Processing for navrongo.
# _______________________________
# Processing for bouake.
# _______________________________
# Processing for bandiagara.
# _______________________________
# Processing for abonnema.
# _______________________________
# Processing for kankan.
# _______________________________
# Processing for hun.
# _______________________________
# Processing for bolgatanga.
# _______________________________
# Processing for mubi.
# _______________________________
# Processing for sangmelima.
# _______________________________
# Processing for ilesha.
# _______________________________
# Processing for gbarnga.
# _______________________________
# Processing for mizdah.
# _______________________________
# Processing for sembe.
# Missing field/result... skipping.
# Processing for ferkessedougou.
# _______________________________
# Processing for lola.
# _______________________________
# Processing for pobe.
# _______________________________
# Processing for enugu.
# _______________________________
# Processing for kontagora.
# _______________________________
# Processing for tera.
# _______________________________
# Processing for ikorodu.
# _______________________________
# Processing for khorixas.
# _______________________________
# Processing for boke.
# _______________________________
# Processing for winneba.
# _______________________________
# Processing for cabinda.
# _______________________________
# Processing for ndioum.
# _______________________________
# Processing for filingue.
# _______________________________
# Processing for begoro.
# _______________________________
# Processing for mokolo.
# _______________________________
# Processing for sokolo.
# _______________________________
# Processing for nara.
# _______________________________
# Processing for baoma.
# _______________________________
# Processing for loandjili.
# _______________________________
# Processing for san-pedro.
# _______________________________
# Processing for foumban.
# _______________________________
# Processing for ouargaye.
# _______________________________
# Processing for quebo.
# Missing field/result... skipping.
# Processing for sumbuya.
# _______________________________
# Processing for beyla.
# _______________________________
# Processing for sikasso.
# _______________________________
# Processing for hounde.
# _______________________________
# Processing for kaduna.
# _______________________________
# Processing for bafut.
# _______________________________
# Processing for betare oya.
# _______________________________
# Processing for kita.
# _______________________________
# Processing for ikole.
# Missing field/result... skipping.
# Processing for gboko.
# _______________________________
# Processing for shagamu.
# _______________________________
# Processing for asamankese.
# _______________________________
# Processing for dabakala.
# _______________________________
# Processing for solenzo.
# _______________________________
# Processing for dano.
# _______________________________
# Processing for kribi.
# _______________________________
# Processing for lafiagi.
# _______________________________
# Processing for koulikoro.
# _______________________________
# Processing for kangaba.
# _______________________________
# Processing for tokonou.
# _______________________________
# Processing for sokode.
# _______________________________
# Processing for minna.
# _______________________________
# Processing for cape coast.
# _______________________________
# Processing for gombe.
# _______________________________
# Processing for lambarene.
# _______________________________
# Processing for kintampo.
# _______________________________
# Processing for jojoima.
# _______________________________
# Processing for nouna.
# _______________________________
# Processing for bonoua.
# _______________________________
# Processing for tignere.
# _______________________________
# Processing for dedougou.
# _______________________________
# Processing for mfou.
# _______________________________
# Processing for okitipupa.
# _______________________________
# Processing for thilogne.
# Missing field/result... skipping.
# Processing for faranah.
# _______________________________
# Processing for kpandae.
# _______________________________
# Processing for orodara.
# _______________________________
# Processing for meiganga.
# _______________________________
# Processing for idanre.
# _______________________________
# Processing for kimparana.
# _______________________________
# Processing for tibati.
# _______________________________
# Processing for nkayi.
# _______________________________
# Processing for gorom-gorom.
# _______________________________
# Processing for lagdo.
# _______________________________
# Processing for mbini.
# _______________________________
# Processing for agogo.
# _______________________________
# Processing for anyama.
# _______________________________
# Processing for libreville.
# _______________________________
# Processing for limbe.
# _______________________________
# Processing for bansang.
# _______________________________
# Processing for nanga eboko.
# _______________________________
# Processing for maroua.
# _______________________________
# Processing for ankpa.
# _______________________________
# Processing for kouroussa.
# _______________________________
# Processing for gaoual.
# _______________________________
# Processing for bousse.
# _______________________________
# Processing for forecariah.
# _______________________________
# Processing for accra.
# _______________________________
# Processing for boromo.
# _______________________________
# Processing for podor.
# _______________________________

# %%
#df = df.dropna(how='any')
cities_pd = cities_pd.dropna(how='any')
cities_pd["Max Temp"] = pd.to_numeric(cities_pd["Max Temp"])
cities_pd["Lat"] = pd.to_numeric(cities_pd["Lat"])
cities_pd["Lng"] = pd.to_numeric(cities_pd["Lng"])
cities_pd["Cloudiness"] = pd.to_numeric(cities_pd["Cloudiness"])
cities_pd["Humidity"] = pd.to_numeric(cities_pd["Humidity"])
cities_pd["Windspeed"] = pd.to_numeric(cities_pd["Windspeed"])
cities_pd.dtypes
# Out:
# City           object
# Cloudiness    float64
# Country        object
# Humidity      float64
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Windspeed     float64
# dtype: object

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
cities_pd
# Out:
#             City  Cloudiness Country  Humidity        Date    Lat     Lng  \
# 0          bilma         0.0      NE      18.0  1575689017  18.69   12.92
# 1     georgetown        40.0      GY     100.0  1575688797   6.80  -58.16
# 2          gusau        76.0      NG      20.0  1575689017  12.17    6.66
# 3      taoudenni       100.0      ML      28.0  1575689017  22.68   -3.98
# 4           lere         7.0      TD      19.0  1575689017   9.66   14.23
# 5           atar       100.0      MR      46.0  1575689018  20.52  -13.05
# 6          kidal       100.0      ML      12.0  1575689018  18.44    1.41
# 7        maghama         NaN               NaN                NaN     NaN
# 8            epe        75.0      DE      87.0  1575689018  52.18    7.04
# 9            gat        48.0      SN      82.0  1575689018  14.69  -16.54
# 10         djibo         0.0      BF      16.0  1575689018  14.10   -1.63
# 11        agadez         1.0      NE      18.0  1575689018  16.97    7.99
# 12   port-gentil       100.0      GA      86.0  1575689018  -0.72    8.78
# 13     jamestown         0.0      AU      13.0  1575689018 -33.21  138.60
# 14        tahoua        25.0      NE      17.0  1575689018  14.89    5.26
# 15   henties bay         0.0      NA      91.0  1575689019 -22.12   14.28
# 16     ogaminana         0.0      NG      47.0  1575689019   7.60    6.20
# 17          luba         0.0      PH      61.0  1575689019  17.32  120.70
# 18        soubre        96.0      CI      93.0  1575689019   5.79   -6.61
# 19          axim        50.0      GH      88.0  1575689019   4.87   -2.24
# 20        luanda        75.0      AO      78.0  1575689019  -8.83   13.24
# 21        harper         1.0      US      53.0  1575689019  30.30  -99.24
# 22      luderitz        39.0      NA      93.0  1575689019 -26.65   15.16
# 23        namibe        68.0      AO      80.0  1575689019 -15.19   12.15
# 24         tabou        83.0      CI      93.0  1575689019   4.42   -7.36
# 25      tessalit        74.0      ML      13.0  1575689019  20.20    1.01
# 26    walvis bay        88.0      NA      88.0  1575689019 -22.95   14.51
# 27       mayumba       100.0      GA      93.0  1575689020  -3.44   10.65
# 28     marrakesh        75.0      MA      87.0  1575689020  31.63   -7.99
# 29       bertoua        48.0      CM      53.0  1575689020   4.58   13.68
# ..           ...         ...     ...       ...         ...    ...     ...
# 247     dedougou         2.0      BF      13.0  1575689039  12.47   -3.47
# 248         mfou        75.0      CM     100.0  1575689039   3.72   11.64
# 249    okitipupa        84.0      NG      93.0  1575689039   6.50    4.78
# 250     thilogne         NaN               NaN                NaN     NaN
# 251      faranah         0.0      GN      42.0  1575689039  10.04  -10.74
# 252      kpandae       100.0      GH      52.0  1575689039   8.46   -0.01
# 253      orodara         0.0      BF      48.0  1575689040  10.98   -4.92
# 254     meiganga        93.0      CM      31.0  1575689040   6.52   14.29
# 255       idanre        44.0      NG      85.0  1575689040   7.11    5.11
# 256    kimparana         0.0      ML      12.0  1575689040  12.83   -4.92
# 257       tibati        33.0      CM      32.0  1575689040   6.47   12.63
# 258        nkayi       100.0      CG      97.0  1575689040  -4.18   13.29
# 259  gorom-gorom       100.0      BF      18.0  1575689040  14.45   -0.24
# 260        lagdo         4.0      CM      22.0  1575689040   9.06   13.67
# 261        mbini        40.0      GQ     100.0  1575689040   1.58    9.62
# 262        agogo        52.0      GH      79.0  1575689040   6.80   -1.08
# 263       anyama        20.0      CI      94.0  1575689042   5.50   -4.06
# 264   libreville        40.0      GA      88.0  1575688977   0.39    9.45
# 265        limbe        91.0      MW      92.0  1575689042 -15.81   35.05
# 266      bansang       100.0      GM      29.0  1575689042  13.44  -14.66
# 267  nanga eboko        84.0      CM      88.0  1575689042   4.68   12.37
# 268       maroua         0.0      CM      20.0  1575689042  10.60   14.33
# 269        ankpa       100.0      NG      37.0  1575689042   7.37    7.63
# 270    kouroussa        46.0      GN      38.0  1575689042  10.65   -9.88
# 271       gaoual         0.0      GN      35.0  1575689042  11.75  -13.20
# 272       bousse        75.0      FR      93.0  1575688764  49.28    6.20
# 273   forecariah         0.0      GN      73.0  1575689042   9.43  -13.09
# 274        accra       100.0      GH      88.0  1575688788   5.56   -0.21
# 275       boromo        42.0      BF      14.0  1575689043  11.74   -2.93
# 276        podor        78.0      MR      40.0  1575689043  16.65  -14.96
#
#      Max Temp  Windspeed
# 0       18.98       3.36
# 1       25.00       2.10
# 2       20.38       4.74
# 3       18.85       3.62
# 4       20.65       1.98
# 5       15.14       3.69
# 6       20.13       5.24
# 7         NaN        NaN
# 8        9.00       8.20
# 9       19.00       6.20
# 10      21.41       3.33
# 11      18.00       3.10
# 12      25.54       5.90
# 13      29.08       3.69
# 14      19.00       3.10
# 15      18.89       0.45
# 16      22.83       0.22
# 17      28.40       5.13
# 18      22.69       1.24
# 19      24.33       0.84
# 20      26.00       1.50
# 21      12.78       1.50
# 22      17.00       1.50
# 23      21.73       3.52
# 24      23.83       1.14
# 25      19.47       4.98
# 26      18.89       1.00
# 27      24.67       3.17
# 28      12.00       1.50
# 29      19.04       0.97
# ..        ...        ...
# 247     20.76       1.88
# 248     22.00       1.00
# 249     23.44       0.64
# 250       NaN        NaN
# 251     19.39       1.24
# 252     27.06       1.36
# 253     18.00       3.10
# 254     16.14       1.26
# 255     23.31       0.42
# 256     22.80       3.55
# 257     18.50       1.58
# 258     21.85       0.73
# 259     22.79       3.72
# 260     20.16       0.80
# 261     25.00       3.60
# 262     24.38       1.84
# 263     26.00       1.00
# 264     26.00       3.10
# 265     18.75       1.33
# 266     19.71       2.17
# 267     18.68       1.17
# 268     20.52       4.09
# 269     22.58       0.71
# 270     20.51       0.82
# 271     20.58       0.71
# 272      9.00       7.20
# 273     22.50       0.63
# 274     26.00       2.10
# 275     22.39       2.15
# 276     19.51       3.40
#
# [277 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
#### Latitude vs. Temperature Plot
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Max Temp"]
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Temperature (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Humidity"]
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Humidity (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Cloudiness"]
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Cloudiness (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create data
N = len(cities_pd)
x = cities_pd["Lat"]
y = cities_pd["Windspeed"]
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('City Latitude vs Windspeed (12/6/19)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
